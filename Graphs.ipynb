# %%
#import libraries
# !pip install pandas-datareader
import pandas as pd
from IPython.display import Image
import numpy as np
import pandas_datareader as web
# %matplotlib inline
import matplotlib.pyplot as plt
import math

# %%
equity_df = pd.read_csv('Equity_perportfolioB.csv')
equity_df1 = pd.read_csv('Equity_perportfolioA.csv')
del equity_df['Unnamed: 0']
del equity_df1['Unnamed: 0']
#latest scipy returns
plt.hist(equity_df1, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("Random Forest Portfolio equity Distribution - Model 1")
plt.legend()
plt.show();
plt.hist(equity_df, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("Random Forest Portfolio equity Distribution - Model 2")
plt.legend()
plt.show();

# %%
MSE_values_df = pd.read_csv('MSE_valuesB.csv')
MSE_values_df1 = pd.read_csv('MSE_valuesA.csv')
del MSE_values_df['Unnamed: 0']
del MSE_values_df1['Unnamed: 0']
plt.hist(MSE_values_df1, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("MSE Distribution - Model 1")
plt.legend()
plt.show();
plt.hist(MSE_values_df, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("MSE Distribution - Model 2")
plt.legend()
plt.show();

# %%
MAE_values_df = pd.read_csv('MAE_valuesB.csv')
MAE_values_df1 = pd.read_csv('MAE_valuesA.csv')
del MAE_values_df['Unnamed: 0']
del MAE_values_df1['Unnamed: 0']
plt.hist(MAE_values_df1, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("MSE Distribution - Model 1")
plt.legend()
plt.show();
plt.hist(MAE_values_df, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("MSE Distribution - Model 2")
plt.legend()
plt.show();

# %%
RMSE_values_df = pd.read_csv('RMSE_valuesB.csv')
RMSE_values_df1 = pd.read_csv('RMSE_valuesA.csv')
del RMSE_values_df['Unnamed: 0']
del RMSE_values_df1['Unnamed: 0']
plt.hist(RMSE_values_df1, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("RMSE Distribution - Model 1")
plt.legend()
plt.show();
plt.hist(RMSE_values_df, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("RMSE Distribution - Model 2")
plt.legend()
plt.show();

# %%
Excessreturn_df = pd.read_csv('ExcessreturnB.csv')
Excessreturn_df1 = pd.read_csv('ExcessreturnA.csv')
del Excessreturn_df['Unnamed: 0']
del Excessreturn_df1['Unnamed: 0']
plt.hist(Excessreturn_df1, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("Excessreturn Distribution - Model 1")
plt.legend()
plt.show();
plt.hist(Excessreturn_df, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("Excessreturn Distribution - Model 2")
plt.legend()
plt.show();

# %%
standarddev_vals_df = pd.read_csv('standarddev_valsB.csv')
standarddev_vals_df1 = pd.read_csv('standarddev_valsA.csv')
del standarddev_vals_df['Unnamed: 0']
del standarddev_vals_df1['Unnamed: 0']
plt.hist(standarddev_vals_df1, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("standarddev Distribution - Model 1")
plt.legend()
plt.show();
plt.hist(standarddev_vals_df, bins = 10, label = 'equity', alpha = 1)#,# color = 'blue') 
plt.title("standarddev Distribution - Model 2")
plt.legend()
plt.show();
